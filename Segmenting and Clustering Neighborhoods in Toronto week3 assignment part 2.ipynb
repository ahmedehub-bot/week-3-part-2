# %% [markdown]
# this note book for preprocessing data and removing  merging duplicated post codes in one cell

# %%
import pandas as pd
import numpy as np
import matplotlib as pl
import matplotlib.pyplot as mp
# %matplotlib inline

# %%
online_data=pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')

# %%
neighbor_toronto_data=online_data[0]

# %%
dft=pd.DataFrame (neighbor_toronto_data)

# %%
dft.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
data_toronto= dft[dft['Borough']!='Not assigned']

# %%
data_toronto.head(20)
# Out:
#    Postcode           Borough     Neighbourhood
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M6A        North York  Lawrence Heights
# 6       M6A        North York    Lawrence Manor
# 7       M7A      Queen's Park      Not assigned
# 9       M9A      Queen's Park      Queen's Park
# 10      M1B       Scarborough             Rouge
# 11      M1B       Scarborough           Malvern
# 13      M3B        North York   Don Mills North
# 14      M4B         East York  Woodbine Gardens
# 15      M4B         East York     Parkview Hill
# 16      M5B  Downtown Toronto           Ryerson
# 17      M5B  Downtown Toronto   Garden District
# 18      M6B        North York         Glencairn
# 21      M9B         Etobicoke        Cloverdale
# 22      M9B         Etobicoke         Islington
# 23      M9B         Etobicoke      Martin Grove
# 24      M9B         Etobicoke  Princess Gardens
# ...

# %%
data_toronto.groupby('Postcode')

# %%
data_toronto.drop_duplicates()
# Out:
#     Postcode           Borough  \
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M6A        North York
# 6        M6A        North York
# 7        M7A      Queen's Park
# 9        M9A      Queen's Park
# 10       M1B       Scarborough
# 11       M1B       Scarborough
# 13       M3B        North York
# 14       M4B         East York
# 15       M4B         East York
# 16       M5B  Downtown Toronto
# 17       M5B  Downtown Toronto
# 18       M6B        North York
# 21       M9B         Etobicoke
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M1C       Scarborough
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 30       M3C        North York
# 31       M3C        North York
# 32       M4C         East York
# 33       M5C  Downtown Toronto
# 34       M6C              York
# 37       M9C         Etobicoke
# ...

# %%
Toronot_coll=data_toronto.groupby(['Postcode','Borough'], sort = False).agg(lambda x: ','.join(x))

# %%
Toronot_coll
# Out:
#                                                                Neighbourhood
# Postcode Borough
# M3A      North York                                                Parkwoods
# M4A      North York                                         Victoria Village
# M5A      Downtown Toronto                                       Harbourfront
# M6A      North York                          Lawrence Heights,Lawrence Manor
# M7A      Queen's Park                                           Not assigned
# M9A      Queen's Park                                           Queen's Park
# M1B      Scarborough                                           Rouge,Malvern
# M3B      North York                                          Don Mills North
# M4B      East York                            Woodbine Gardens,Parkview Hill
# M5B      Downtown Toronto                            Ryerson,Garden District
# M6B      North York                                                Glencairn
# ...

# %%
Toronot_coll['Neighbourhood']=Toronot_coll['Neighbourhood'].replace('Not assigned', "Queen's Park")

# %%
Toronot_coll.reset_index(inplace=True)

# %% [markdown]
# this is the last cell shows the head of the dataframe('Toronot_coll')

# %%
#the head (five frist rows ) of the dataframe 
Toronot_coll.head()
# Out:
#   Postcode           Borough                    Neighbourhood
# 0      M3A        North York                        Parkwoods
# 1      M4A        North York                 Victoria Village
# 2      M5A  Downtown Toronto                     Harbourfront
# 3      M6A        North York  Lawrence Heights,Lawrence Manor
# 4      M7A      Queen's Park                     Queen's Park

# %%
Toronot_coll.head(5)
# Out:
#   Postcode           Borough                    Neighbourhood
# 0      M3A        North York                        Parkwoods
# 1      M4A        North York                 Victoria Village
# 2      M5A  Downtown Toronto                     Harbourfront
# 3      M6A        North York  Lawrence Heights,Lawrence Manor
# 4      M7A      Queen's Park                     Queen's Park

# %%
lati_longti= pd.read_csv('Geospatial_Coordinates.csv')

# %%
lati_longti.rename(columns={'Postal Code':'Postcode'},inplace=True)

# %%
lati_longti.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %%
sorted_Tornot_data=pd.merge(Toronot_coll,lati_longti,on=['Postcode'])

# %%
sorted_Tornot_data.head(15)
# Out:
#    Postcode           Borough  \
# 0       M3A        North York
# 1       M4A        North York
# 2       M5A  Downtown Toronto
# 3       M6A        North York
# 4       M7A      Queen's Park
# 5       M9A      Queen's Park
# 6       M1B       Scarborough
# 7       M3B        North York
# 8       M4B         East York
# 9       M5B  Downtown Toronto
# 10      M6B        North York
# 11      M9B         Etobicoke
# 12      M1C       Scarborough
# 13      M3C        North York
# 14      M4C         East York
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                           Parkwoods  43.753259 -79.329656
# 1                                    Victoria Village  43.725882 -79.315572
# 2                                        Harbourfront  43.654260 -79.360636
# 3                     Lawrence Heights,Lawrence Manor  43.718518 -79.464763
# 4                                        Queen's Park  43.662301 -79.389494
# ...
